# %%
import duckdb
import pandas as pd

EMBEDDINGS_FILE = "app_duckdb\data\embeddings.duckdb"

search_word = "disconnected" # Substitua pela palavra que você quer pesquisar

with duckdb.connect(EMBEDDINGS_FILE) as conn:
    result = conn.execute(f"""
        SELECT id, text
        FROM embeddings
        WHERE text LIKE '%{search_word}%'
        LIMIT 5
    """).fetchdf()

print(f"\nComentários contendo '{search_word}':")
texts_series = result['text']
for text in texts_series:
    print('\n')
    print(text)
# Out:
# Comentários contendo 'disconnected':
#
#
# Sam was great. Chris was great. A little disconnected in some ways ... but pretty authentic conversation.
